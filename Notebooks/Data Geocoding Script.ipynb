# %%
import pandas as pd
import time

# %% [markdown]
# Import officer-involved fatality data from WaPo Github repo

# %%
fatalities = pd.read_csv('https://raw.githubusercontent.com/washingtonpost/data-police-shootings/master/fatal-police-shootings-data.csv')

# %% [markdown]
# Concatenate 'city' and 'state' values into a location name that can be geocoded

# %%
fatalities['location'] = fatalities[['city', 'state']].apply(lambda x: ', '.join(x), axis=1)

# %% [markdown]
# Read unique locations into a list

# %%
locations = []

for i in fatalities.location.unique():
    locations.append(i)

# %% [markdown]
# Convert to pandas series object

# %%
locations = pd.DataFrame(locations)

# %%
locations
# Out:
#                           0
# 0               Shelton, WA
# 1                 Aloha, OR
# 2               Wichita, KS
# 3         San Francisco, CA
# 4                 Evans, CO
# 5               Guthrie, OK
# 6              Chandler, AZ
# 7               Assaria, KS
# 8            Burlington, IA
# 9             Knoxville, PA
# 10             Stockton, CA
# 11             Freeport, TX
# 12             Columbus, OH
# 13           Des Moines, IA
# 14          New Orleans, LA
# 15              Huntley, MT
# 16       Salt Lake City, UT
# 17               Strong, AR
# 18             Syracuse, UT
# 19              England, AR
# 20              El Paso, TX
# 21               Arcola, IL
# 22           South Gate, CA
# 23      North Las Vegas, NV
# 24          Albuquerque, NM
# 25           Jourdanton, TX
# 26             St. Paul, MN
# 27      Franklin County, MO
# 28           Chesapeake, VA
# 29           Old Bridge, NJ
# ...                     ...
# 2408             Wesson, MS
# 2409           Ranburne, AL
# 2410        Asbury Park, NJ
# 2411      Ross Township, PA
# 2412         Port Allen, LA
# 2413           Hartford, CT
# 2414      Three Springs, PA
# 2415           Sun City, SC
# 2416       Boyton Beach, FL
# 2417        Stroudsburg, PA
# 2418     Council Bluffs, IA
# 2419     Jackson County, KY
# 2420         Charlottte, NC
# 2421             Revere, MA
# 2422      Safety Harbor, FL
# 2423         Hanceville, AL
# 2424         Aliceville, CA
# 2425             Lowell, AR
# 2426          Irvington, NJ
# 2427  Pocahontas County, WV
# 2428              Rifle, CO
# 2429    Shaler Township, PA
# 2430         Moss Point, MS
# 2431     Bradley County, TN
# 2432    Randolph County, NC
# 2433            Chetopa, KS
# 2434             Belton, SC
# 2435     Spokane Valley, WA
# 2436        Springville, IN
# 2437          Caledonia, WI
#
# [2438 rows x 1 columns]

# %% [markdown]
# Rename column

# %%
locations = locations.rename({0: "location"}, axis = 1)

# %%
locations.head()
# Out:
#             location
# 0        Shelton, WA
# 1          Aloha, OR
# 2        Wichita, KS
# 3  San Francisco, CA
# 4          Evans, CO

# %% [markdown]
# Export dataframe as input .csv for geocoding script; output will be 'fatalities_geocoded.csv'

# %%
locations.to_csv('locations.csv')

# %%
# importing csv module
import csv
import requests
import time

GOOGLE_MAPS_API_URL = 'https://maps.googleapis.com/maps/api/geocode/json?key=[YOUR API KEY HERE]'

infile = "locations.csv"
outfile = "fatalities_geocoded.csv"
rows = []

# reading csv file
with open(infile, 'r') as csvfile:
    # creating a csv reader object
    csvreader = csv.reader(csvfile)

    # extracting each data row one by one
    for row in csvreader:
        rows.append(row)

    # get total number of rows
    print("Total no. of rows: %d"%(csvreader.line_num))

for row in rows:
    address = row[-1]
    print("Processing: " + address)

    params = {
                'address': address,
                'sensor': 'false',
                'region': 'USA'
            }

    # Do the request and get the response data
    req = requests.get(GOOGLE_MAPS_API_URL, params=params)
    res = req.json()

    # Use the first result
    if(len(res['results']) > 0):

        result = res['results'][0]

        geodata = dict()
        geodata['lat'] = result['geometry']['location']['lat']
        geodata['lng'] = result['geometry']['location']['lng']

        # check if the coordinates were found
        if(geodata['lat'] is not None and geodata['lng'] is not None):
            row.append(geodata['lat'])
            row.append(geodata['lng'])

    else:
        print("Some problems with finding the coordinates. ", res);

#     time.sleep(2)


with open(outfile, 'w') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(rows)

csvfile.close()
writeFile.close()
# Out:
# Total no. of rows: 63
# Processing: location
# Processing: Guthrie, OK
# Processing: Burlington, IA
# Processing: Columbus, OH
# Processing: New Orleans, LA
# Processing: South Gate, CA
# Processing: Albuquerque, NM
# Processing: Jourdanton, TX
# Processing: Old Bridge, NJ
# Processing: Fort Worth, TX
# Processing: Hemet, CA
# Processing: Austin, TX
# Processing: Phoenix, AZ
# Processing: Stillwater, OK
# Processing: Tempe, AZ
# Processing: Smyrna, ME
# Processing: Kansas City, KS
# Processing: Tarboro, NC
# Processing: Medford, OR
# Processing: Dublin, NC
# Processing: Glendale, AZ
# Processing: Harmony, IN
# Processing: Islip, NY
# Processing: Winchester, VA
# Processing: Wilmore, KY
# Processing: Sidney, NE
# Processing: Kings County, CA
# Processing: Marion, IL
# Processing: Ft. Lauderdale, FL
# Processing: Byram, NJ
# Processing: Olivehurst, CA
# Processing: Fort Collins, CO
# Processing: Roswell, NM
# Processing: Nitro, WV
# Processing: Boerne, TX
# Processing: West Chester, PA
# Processing: Cushing, OK
# Processing: Artesia, NM
# Processing: Mitchell, SD
# Processing: El Monte, CA
# Processing: Chalmette, LA
# Processing: Niceville, FL
# Processing: Beckley, WV
# Processing: Kirkland, WA
# Processing: Columbus, MS
# Processing: Colorado Springs, CO
# Processing: Hutchinson, MN
# Processing: Marksville, LA
# Processing: Hominy, OK
# Processing: Brighton, CO
# Processing: Arlington, GA
# Processing: Norwalk, CA
# Processing: Mount Washington, PA
# Processing: Marina, CA
# Processing: Mount Hope, WV
# Processing: Kent, OH
# Processing: Porterville, CA
# Processing: Rising Sun, MD
# Processing: Hurst, IL
# Processing: Phenix City, AL
# Processing: Barrow, AK
# Processing: Maiden, NC
# Processing: Roanoke, VA

# %% [markdown]
# I fixed column headers in the .csv files manually in order to quickly join the two dataframes. The only reason I even had to join dataframes is because of Google API errors during geocoding (62 of them, evidently).

# %%
non_geocoded_data = non_geocoded_data.drop(["latitude", "longitude"], axis = 1)

# %%
non_geocoded_data.to_csv('non_geocoded_data.csv')

# %%
re_geocoded_data = pd.read_csv('re_geocoded_data.csv')

# %%
test = geocoded_data.append(re_geocoded_data)

# %%
test = pd.concat([geocoded_data, re_geocoded_data])

# %%
len(test)
# Out:
# 2438

# %%
test.to_csv('master_data.csv')

# %%
len(df[df.state=='AK'])
# Out:
# 31

# %%
geocoded_without_counts = pd.read_csv('static/data/master_data.csv')

# %%
geocoded_without_counts = geocoded_without_counts.sort_values(by = 'location', ascending = True)

# %%
df = pd.read_csv('static/data/data.csv')

# %%
df = df.sort_values(by = 'location', ascending = True)

# %%
counts = pd.Series(df['location'].value_counts())

# %%
counts = pd.DataFrame(counts)

# %%
counts = counts.reset_index()

# %%
counts = counts.rename(columns = {'index' : 'location', 'location' : 'fatality_count'})

# %%
counts = counts.sort_values(by = 'location', ascending = True)

# %%
geocoded_without_counts['fatality_count'] = counts['fatality_count']

# %%
counts[counts['location'] == 'Los Angeles, CA']
# Out:
#           location  fatality_count
# 0  Los Angeles, CA              69

# %%
geocoded_without_counts[geocoded_without_counts['location'] == 'Los Angeles, CA']
# Out:
#     Unnamed: 0         location   latitude   longitude  fatality_count
# 32          40  Los Angeles, CA  34.052234 -118.243685              14

# %%
join = pd.merge(geocoded_without_counts, counts, on=['location'])

# %%
join[join.location == 'Los Angeles, CA']
# Out:
#       Unnamed: 0         location   latitude   longitude  fatality_count
# 1266          40  Los Angeles, CA  34.052234 -118.243685              69

# %%
join = join.drop('Unnamed: 0', axis = 1)

# %%
join.to_csv('geocoded_locations_with_fatality_counts.csv')

# %%
 = df[df.date.str.contains('2015')]
test = df[df.date.str.contains('2017')]      
test = df[df.date.str.contains('2017')]      
test = df[df.date.str.contains('2017')]      
test = df[df.date.str.contains('2017')]      
test = df[df.date.str.contains('2017')]

# %%
len(test)
# Out:
# 986

# %%
df.date.unique()
# Out:
# array(['2017-12-26', '2017-06-02', '2018-07-28', ..., '2015-04-03',
#        '2018-03-26', '2015-06-24'], dtype=object)

# %%
years = ['2015', '2016', '2017', '2018', '2019']
for i in years:
    date_pull = df[df.date.str.contains(i)]
    date_pull = date_pull.drop(['Unnamed: 0', 'id'], axis = 1)
    date_pull.to_csv(i+'.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4519 entries, 2928 to 252
# Data columns (total 16 columns):
# Unnamed: 0                 4519 non-null int64
# id                         4519 non-null int64
# name                       4519 non-null object
# date                       4519 non-null object
# manner_of_death            4519 non-null object
# armed                      4271 non-null object
# age                        4341 non-null float64
# gender                     4515 non-null object
# race                       4116 non-null object
# city                       4519 non-null object
# state                      4519 non-null object
# signs_of_mental_illness    4519 non-null bool
# threat_level               4519 non-null object
# flee                       4339 non-null object
# body_camera                4519 non-null bool
# location                   4519 non-null object
# dtypes: bool(2), float64(1), int64(2), object(11)
# memory usage: 538.4+ KB

# %%
len(df[df.armed == 'unarmed'])
# Out:
# 289

# %%
len(df[df.signs_of_mental_illness == True]) / len(df) * 100
# Out:
# 23.58928966585528

# %%
df.threat_level.unique()
# Out:
# array(['other', 'attack', 'undetermined'], dtype=object)

# %%
(len(df[df.threat_level == 'other']) + len(df[df.threat_level == 'undetermined'])) / len(df) * 100
# Out:
# 36.60101792431954

# %%
(len(df[df.flee == 'Not fleeing']) / len(df)) * 100
# Out:
# 63.99645939367117

# %%
df.flee.unique()
# Out:
# array(['Other', 'Not fleeing', 'Foot', 'Car', nan], dtype=object)

# %%
import pandas as pd

# %%
fatalities = pd.read_csv('static/data/data.csv')

# %%
geocoded_locations = pd.read_csv('static/data/master_data.csv')

# %%
join = pd.merge(fatalities, geocoded_locations, on=['location'])

# %%
join
# Out:
#       Unnamed: 0_x    id                        name        date  \
# 0                0     3                  Tim Elliot  2015-01-02
# 1                1     4            Lewis Lee Lembke  2015-01-02
# 2              747   890        Phyllis Ilene Jepsen  2015-10-02
# 3                2     5          John Paul Quintero  2015-01-03
# 4              634   765             Nicholas Garner  2015-08-22
# 5             1647  1843            Caleb J. Douglas  2016-09-01
# 6             2190  2437              Kevin C. Perry  2017-03-18
# 7             2565  2848                  Jose Ortiz  2017-08-07
# 8             2931  3250                Andrew Finch  2017-12-27
# 9             3965  4374             Geoffrey Morris  2019-01-10
# 10            4018  4424    David Michael Bosiljevac  2019-01-28
# 11            4307  4738              Robert Sabater  2019-05-27
# 12               3     8             Matthew Hoffman  2015-01-04
# 13             142   182         Amilcar Perez-Lopez  2015-02-26
# 14             201   221                 Alice Brown  2015-03-17
# 15             781   922             Herbert Benitez  2015-10-15
# 16             855   998         Javier Lopez Garcia  2015-11-11
# 17             911  1052                 Mario Woods  2015-12-02
# 18            1266  1443                Luis Gongora  2016-04-07
# 19            1365  1548     Jessica Nelson-Williams  2016-05-19
# 20            1760  1970          Nicholas McWherter  2016-10-14
# 21            2298  2556            Nicholas Flusche  2017-05-03
# 22            2346  2603                    John Eno  2017-05-23
# 23            2681  2975               Damien Murray  2017-09-24
# 24            2865  3176                Keita O'Neil  2017-12-01
# 25            3143  3478        Jesus Delgado-Duarte  2018-03-06
# 26            3196  3534                   Jehad Eid  2018-03-21
# 27               4     9           Michael Rodriguez  2015-01-04
# 28            1151  1312                 Luke Miller  2016-02-25
# 29               5    11           Kenneth Joe Brown  2015-01-04
# ...            ...   ...                         ...         ...
# 4489          4443  4888             Shawan F. Allen  2019-07-22
# 4490          4444  4893            John David Brown  2019-07-22
# 4491          4445  4886                 James Manzo  2019-07-23
# 4492          4446  4887              Omari Thompson  2019-07-23
# 4493          4448  4894      Josef Delon Richardson  2019-07-25
# 4494          4449  4896            Alphonso Zaporta  2019-07-26
# 4495          4450  4897                Todd Messner  2019-07-26
# 4496          4451  4901    Donald Williams Allamong  2019-07-26
# 4497          4453  4895  Adalberto Wolmar Rodriguez  2019-07-28
# 4498          4454  4905             Larry Pettiford  2019-07-28
# 4499          4460  4950               Troy Peterson  2019-07-31
# 4500          4466  4925            David Willoughby  2019-08-01
# 4501          4468  4908             Delano Williams  2019-08-02
# 4502          4472  4915      Oscar Ventura-Gonzalez  2019-08-03
# 4503          4473  4918                  John Clark  2019-08-03
# 4504          4477  4909        Robert Clay Wilsford  2019-08-04
# 4505          4478  4948               Marvin Urbina  2019-08-04
# 4506          4482  4947            Derrick Davidson  2019-08-05
# 4507          4483  4953              Kaizen Crossen  2019-08-05
# 4508          4484  4954               William Biggs  2019-08-05
# 4509          4485  4955                Allan George  2019-08-05
# 4510          4486  4936               Donald Babbit  2019-08-06
# 4511          4488  4930       Toussaint Diamon Sims  2019-08-08
# 4512          4494  4929       Manuel Charles Carter  2019-08-10
# 4513          4497  4944          Cole Steele Jessup  2019-08-12
# 4514          4499  4949               Scott Souders  2019-08-12
# 4515          4504  4946     Thomas Michael Reynolds  2019-08-14
# 4516          4507  4967                       TK TK  2019-08-16
# 4517          4510  4962                Mike Parsley  2019-08-17
# 4518          4515  4971             Jared R. Nelson  2019-08-18
#
#        manner_of_death            armed   age gender race               city  \
# 0                 shot              gun  53.0      M    A            Shelton
# 1                 shot              gun  47.0      M    W              Aloha
# 2                 shot            knife  55.0      F    W              Aloha
# 3     shot and Tasered          unarmed  23.0      M    H            Wichita
# 4                 shot              NaN  26.0      M    W            Wichita
# 5                 shot              gun  18.0      M    W            Wichita
# 6                 shot              gun  25.0      M    W            Wichita
# 7                 shot            knife  29.0      M    H            Wichita
# 8                 shot          unarmed  28.0      M    W            Wichita
# 9                 shot  gun and vehicle  29.0      M    W            Wichita
# 10                shot       toy weapon  55.0      M    W            Wichita
# 11                shot              gun  49.0      M    W            Wichita
# 12                shot       toy weapon  32.0      M    W      San Francisco
# 13                shot            knife  21.0      M    H      San Francisco
# 14                shot              NaN  24.0      F    W      San Francisco
# 15                shot              gun  27.0      M    H      San Francisco
# 16                shot              gun  25.0      M    H      San Francisco
# 17                shot            knife  26.0      M    B      San Francisco
# 18                shot            knife  45.0      M    H      San Francisco
# 19                shot          unarmed  29.0      F    B      San Francisco
# 20                shot              gun  26.0      M    W      San Francisco
# 21                shot            knife  26.0      M    W      San Francisco
# 22                shot              gun  59.0      M    W      San Francisco
# 23                shot              gun  39.0      M    B      San Francisco
# 24                shot          unarmed  42.0      M    B      San Francisco
# 25                shot              gun  19.0      M    H      San Francisco
# 26                shot              gun  21.0      M    A      San Francisco
# 27                shot         nail gun  39.0      M    H              Evans
# 28                shot              gun  37.0      M    W              Evans
# 29                shot              gun  18.0      M    W            Guthrie
# ...                ...              ...   ...    ...  ...                ...
# 4489              shot              gun   NaN      M    B             Wesson
# 4490              shot              gun  53.0      M    W           Ranburne
# 4491              shot         scissors  27.0      M    W        Asbury Park
# 4492              shot              gun  31.0      M    B      Ross Township
# 4493              shot     undetermined  38.0      M    B         Port Allen
# 4494              shot              gun  41.0      M    H           Hartford
# 4495              shot              gun  49.0      M    W      Three Springs
# 4496              shot              gun  56.0      M    W           Sun City
# 4497              shot              gun  62.0      M    H       Boyton Beach
# 4498              shot              gun  69.0      M  NaN        Stroudsburg
# 4499              shot              gun   NaN      M    W     Council Bluffs
# 4500              shot          vehicle  54.0      M  NaN     Jackson County
# 4501              shot              gun  55.0      M  NaN         Charlottte
# 4502              shot              gun  32.0      M    H             Revere
# 4503              shot              gun  35.0      M  NaN      Safety Harbor
# 4504              shot              gun  65.0      M  NaN         Hanceville
# 4505              shot     undetermined  19.0      M  NaN         Aliceville
# 4506              shot     undetermined  56.0      M  NaN             Lowell
# 4507              shot              gun  39.0      M    B          Irvington
# 4508              shot              gun  43.0      M  NaN  Pocahontas County
# 4509              shot              gun  57.0      M  NaN              Rifle
# 4510              shot              gun  49.0      M    W    Shaler Township
# 4511              shot              gun  27.0      M    B         Moss Point
# 4512              shot            knife  57.0      M  NaN     Bradley County
# 4513              shot          vehicle  20.0      M    W    Randolph County
# 4514              shot              gun  38.0      M  NaN            Chetopa
# 4515              shot              gun  37.0      M  NaN             Belton
# 4516              shot              gun   NaN      M  NaN     Spokane Valley
# 4517              shot              gun  62.0      M    W        Springville
# 4518              shot     sharp object  38.0      M  NaN          Caledonia
#
#      state  signs_of_mental_illness  threat_level         flee  body_camera  \
# 0       WA                     True        attack  Not fleeing        False
# 1       OR                    False        attack  Not fleeing        False
# 2       OR                     True         other  Not fleeing        False
# 3       KS                    False         other  Not fleeing        False
# 4       KS                    False        attack          Car        False
# 5       KS                    False         other          Car         True
# 6       KS                    False        attack  Not fleeing        False
# 7       KS                    False         other  Not fleeing        False
# 8       KS                    False         other  Not fleeing        False
# 9       KS                    False        attack          Car        False
# 10      KS                    False        attack  Not fleeing        False
# 11      KS                     True        attack         Foot        False
# 12      CA                     True        attack  Not fleeing        False
# 13      CA                    False         other  Not fleeing        False
# 14      CA                     True         other  Not fleeing        False
# 15      CA                    False        attack  Not fleeing        False
# 16      CA                    False        attack  Not fleeing        False
# 17      CA                    False         other  Not fleeing        False
# 18      CA                    False         other  Not fleeing        False
# 19      CA                    False         other          Car        False
# 20      CA                     True        attack  Not fleeing        False
# 21      CA                    False        attack  Not fleeing         True
# 22      CA                    False         other  Not fleeing        False
# 23      CA                    False         other  Not fleeing         True
# 24      CA                    False         other          Car         True
# 25      CA                    False        attack  Not fleeing        False
# 26      CA                    False        attack  Not fleeing        False
# 27      CO                    False        attack  Not fleeing        False
# 28      CO                    False        attack         Foot         True
# 29      OK                    False        attack  Not fleeing        False
# ...    ...                      ...           ...          ...          ...
# 4489    MS                    False        attack          NaN        False
# 4490    AL                     True        attack  Not fleeing        False
# 4491    NJ                     True         other  Not fleeing        False
# 4492    PA                    False        attack  Not fleeing        False
# 4493    LA                    False  undetermined          NaN        False
# 4494    CT                    False        attack          Car         True
# 4495    PA                    False        attack  Not fleeing        False
# 4496    SC                     True         other  Not fleeing        False
# 4497    FL                    False        attack  Not fleeing        False
# 4498    PA                     True        attack  Not fleeing        False
# 4499    IA                    False        attack          Car        False
# 4500    KY                    False        attack          Car        False
# 4501    NC                     True        attack  Not fleeing        False
# 4502    MA                    False        attack          Car        False
# 4503    FL                    False        attack          Car        False
# 4504    AL                     True        attack  Not fleeing        False
# 4505    CA                    False         other          Car        False
# 4506    AR                     True  undetermined  Not fleeing        False
# 4507    NJ                    False        attack  Not fleeing        False
# 4508    WV                    False        attack          Car        False
# 4509    CO                    False         other  Not fleeing        False
# 4510    PA                    False        attack  Not fleeing        False
# 4511    MS                    False        attack         Foot         True
# 4512    TN                    False        attack  Not fleeing        False
# 4513    NC                    False        attack        Other        False
# 4514    KS                    False        attack  Not fleeing        False
# 4515    SC                    False         other  Not fleeing        False
# 4516    WA                    False        attack          Car        False
# 4517    IN                    False  undetermined  Not fleeing        False
# 4518    WI                    False        attack  Not fleeing        False
#
#                    location  Unnamed: 0_y   latitude   longitude
# 0               Shelton, WA             0  47.215094 -123.100707
# 1                 Aloha, OR             1  45.494284 -122.867045
# 2                 Aloha, OR             1  45.494284 -122.867045
# 3               Wichita, KS             2  37.687176  -97.330053
# 4               Wichita, KS             2  37.687176  -97.330053
# 5               Wichita, KS             2  37.687176  -97.330053
# 6               Wichita, KS             2  37.687176  -97.330053
# 7               Wichita, KS             2  37.687176  -97.330053
# 8               Wichita, KS             2  37.687176  -97.330053
# 9               Wichita, KS             2  37.687176  -97.330053
# 10              Wichita, KS             2  37.687176  -97.330053
# 11              Wichita, KS             2  37.687176  -97.330053
# 12        San Francisco, CA             3  37.774929 -122.419415
# 13        San Francisco, CA             3  37.774929 -122.419415
# 14        San Francisco, CA             3  37.774929 -122.419415
# 15        San Francisco, CA             3  37.774929 -122.419415
# 16        San Francisco, CA             3  37.774929 -122.419415
# 17        San Francisco, CA             3  37.774929 -122.419415
# 18        San Francisco, CA             3  37.774929 -122.419415
# 19        San Francisco, CA             3  37.774929 -122.419415
# 20        San Francisco, CA             3  37.774929 -122.419415
# 21        San Francisco, CA             3  37.774929 -122.419415
# 22        San Francisco, CA             3  37.774929 -122.419415
# 23        San Francisco, CA             3  37.774929 -122.419415
# 24        San Francisco, CA             3  37.774929 -122.419415
# 25        San Francisco, CA             3  37.774929 -122.419415
# 26        San Francisco, CA             3  37.774929 -122.419415
# 27                Evans, CO             4  40.376370 -104.692187
# 28                Evans, CO             4  40.376370 -104.692187
# 29              Guthrie, OK             5  35.878937  -97.425319
# ...                     ...           ...        ...         ...
# 4489             Wesson, MS          2408  31.701277  -90.397593
# 4490           Ranburne, AL          2409  33.522889  -85.344673
# 4491        Asbury Park, NJ          2410  40.220391  -74.012082
# 4492      Ross Township, PA          2411  40.536772  -80.019956
# 4493         Port Allen, LA          2412  30.447488  -91.207326
# 4494           Hartford, CT          2413  41.765804  -72.673372
# 4495      Three Springs, PA          2414  40.195081  -77.983056
# 4496           Sun City, SC          2415  32.287299  -80.970529
# 4497       Boyton Beach, FL          2416  26.531787  -80.090547
# 4498        Stroudsburg, PA          2417  40.986761  -75.194625
# 4499     Council Bluffs, IA          2418  41.261944  -95.860833
# 4500     Jackson County, KY          2419  37.402327  -84.016742
# 4501         Charlottte, NC          2420  35.227087  -80.843127
# 4502             Revere, MA          2421  42.408430  -71.011995
# 4503      Safety Harbor, FL          2422  27.990853  -82.693155
# 4504         Hanceville, AL          2423  34.060654  -86.767498
# 4505         Aliceville, CA          2424  33.129568  -88.151417
# 4506             Lowell, AR          2425  36.255354  -94.130759
# 4507          Irvington, NJ          2426  40.726325  -74.228643
# 4508  Pocahontas County, WV          2427  38.310171  -80.008775
# 4509              Rifle, CO          2428  39.534702 -107.783120
# 4510    Shaler Township, PA          2429  40.530918  -79.952845
# 4511         Moss Point, MS          2430  30.411588  -88.534460
# 4512     Bradley County, TN          2431  35.193778  -84.856793
# 4513    Randolph County, NC          2432  35.744953  -79.829674
# 4514            Chetopa, KS          2433  37.037292  -95.089961
# 4515             Belton, SC          2434  34.522888  -82.494295
# 4516     Spokane Valley, WA          2435  47.673228 -117.239375
# 4517        Springville, IN          2436  38.936160  -86.619442
# 4518          Caledonia, WI          2437  42.807796  -87.924248
#
# [4519 rows x 19 columns]

# %%
join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4519 entries, 0 to 4518
# Data columns (total 19 columns):
# Unnamed: 0_x               4519 non-null int64
# id                         4519 non-null int64
# name                       4519 non-null object
# date                       4519 non-null object
# manner_of_death            4519 non-null object
# armed                      4271 non-null object
# age                        4341 non-null float64
# gender                     4515 non-null object
# race                       4116 non-null object
# city                       4519 non-null object
# state                      4519 non-null object
# signs_of_mental_illness    4519 non-null bool
# threat_level               4519 non-null object
# flee                       4339 non-null object
# body_camera                4519 non-null bool
# location                   4519 non-null object
# Unnamed: 0_y               4519 non-null int64
# latitude                   4519 non-null float64
# longitude                  4519 non-null float64
# dtypes: bool(2), float64(3), int64(3), object(11)
# memory usage: 644.3+ KB

# %%
join = join.drop(['Unnamed: 0_x', 'Unnamed: 0_y', 'id'], axis = 1)

# %%
join.to_csv('fatalities_geocoded.csv')

# %%
len(join)
# Out:
# 4519

# %%
len(fatalities)
# Out:
# 4519
